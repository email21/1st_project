# %%
import pandas as pd
df = pd.read_csv("M_20250714_175227.csv")  # 주택담보대출
df.head()
# Out:
#    dcls_month_x  fin_co_no_x fin_prdt_cd kor_co_nm fin_prdt_nm join_way  \
# 0        202506        10001        1054      우리은행      우리아파트론  영업점,모집인
# 1        202506        10001        1054      우리은행      우리아파트론  영업점,모집인
# 2        202506        10001        1054      우리은행      우리아파트론  영업점,모집인
# 3        202506        10001        1055      우리은행      우리부동산론  영업점,모집인
# 4        202506        10001        1055      우리은행      우리부동산론  영업점,모집인
#
#                                       loan_inci_expn  \
# 0  - 인지세 : 해당세액의 50%(대출금액 5천만원 이하시 없음)\n- 국민주택채권 ...
# 1  - 인지세 : 해당세액의 50%(대출금액 5천만원 이하시 없음)\n- 국민주택채권 ...
# 2  - 인지세 : 해당세액의 50%(대출금액 5천만원 이하시 없음)\n- 국민주택채권 ...
# 3  - 인지세 : 해당세액의 50%(대출금액 5천만원 이하시 없음)\n- 국민주택채권 ...
# 4  - 인지세 : 해당세액의 50%(대출금액 5천만원 이하시 없음)\n- 국민주택채권 ...
#
#                                        erly_rpay_fee  \
# 0  - 고정금리 : 중도상환대출금×0.74%×잔존기간÷대출기간\n- 변동금리 : 중도상...
# 1  - 고정금리 : 중도상환대출금×0.74%×잔존기간÷대출기간\n- 변동금리 : 중도상...
# ...

# %%
df.columns
# Out:
# Index(['dcls_month_x', 'fin_co_no_x', 'fin_prdt_cd', 'kor_co_nm',
#        'fin_prdt_nm', 'join_way', 'loan_inci_expn', 'erly_rpay_fee',
#        'dly_rate', 'loan_lmt', 'dcls_strt_day', 'dcls_end_day',
#        'fin_co_subm_day', 'dcls_month_y', 'fin_co_no_y', 'mrtg_type',
#        'mrtg_type_nm', 'rpay_type', 'rpay_type_nm', 'lend_rate_type',
#        'lend_rate_type_nm', 'lend_rate_min', 'lend_rate_max', 'lend_rate_avg',
#        'region_code', 'region_name'],
#       dtype='object')

# %%
df1 = pd.read_csv("financial_rag/data/raw/D_20250714_175227.csv")  # 예금
df1.head()
# Out:
#    dcls_month_x  fin_co_no_x fin_prdt_cd kor_co_nm fin_prdt_nm  \
# 0        202506        10001     WR0001B      우리은행    WON플러스예금
# 1        202506        10001     WR0001B      우리은행    WON플러스예금
# 2        202506        10001     WR0001B      우리은행    WON플러스예금
# 3        202506        10001     WR0001B      우리은행    WON플러스예금
# 4        202506        10001     WR0001B      우리은행    WON플러스예금
#
#             join_way                                           mtrt_int  \
# 0  인터넷,스마트폰,전화(텔레뱅킹)  만기 후\n- 1개월이내 : 만기시점약정이율×50%\n- 1개월초과 6개월이내: 만...
# 1  인터넷,스마트폰,전화(텔레뱅킹)  만기 후\n- 1개월이내 : 만기시점약정이율×50%\n- 1개월초과 6개월이내: 만...
# 2  인터넷,스마트폰,전화(텔레뱅킹)  만기 후\n- 1개월이내 : 만기시점약정이율×50%\n- 1개월초과 6개월이내: 만...
# 3  인터넷,스마트폰,전화(텔레뱅킹)  만기 후\n- 1개월이내 : 만기시점약정이율×50%\n- 1개월초과 6개월이내: 만...
# 4  인터넷,스마트폰,전화(텔레뱅킹)  만기 후\n- 1개월이내 : 만기시점약정이율×50%\n- 1개월초과 6개월이내: 만...
#
#   spcl_cnd  join_deny join_member  ... fin_co_subm_day  dcls_month_y  \
# 0  해당사항 없음          1      실명의 개인  ...    202507091007        202506
# ...

# %%
df1.columns
# Out:
# Index(['dcls_month_x', 'fin_co_no_x', 'fin_prdt_cd', 'kor_co_nm',
#        'fin_prdt_nm', 'join_way', 'mtrt_int', 'spcl_cnd', 'join_deny',
#        'join_member', 'etc_note', 'max_limit', 'dcls_strt_day', 'dcls_end_day',
#        'fin_co_subm_day', 'dcls_month_y', 'fin_co_no_y', 'intr_rate_type',
#        'intr_rate_type_nm', 'save_trm', 'intr_rate', 'intr_rate2',
#        'region_code', 'region_name'],
#       dtype='object')
